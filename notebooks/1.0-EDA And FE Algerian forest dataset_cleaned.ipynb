# %% [markdown]
# ## **Algerian Forest Fires Dataset**
# Algerian Forest Fires Data from 2012

# %% [markdown]
# About Dataset
#
#  The dataset includes 244 instances that regroup a data of two regions of Algeria, namely the Bejaia region located in the northeast of Algeria and the Sidi Bel-abbes region located in the northwest of Algeria.
#
#  122 instances for each region.
#
#  The period from June 2012 to September 2012.
#  The dataset includes 11 attributes and 1 output attribute (class)
#  The 244 instances have been classified into fire (138 classes) and not fire (106 classes) classes.

# %% [markdown]
# **About Dataset**
#
# **Context**\
# There's a story behind every dataset and here's your opportunity to share yours.
#
# **Content**\
# Attribute Information:
#
# 1. Date : (DD/MM/YYYY) Day, month ('june' to 'september'), year (2012)
# Weather data observations
# 2. Temp : temperature noon (temperature max) in Celsius degrees: 22 to 42
# 3. RH : Relative Humidity in %: 21 to 90
# 4. Ws :Wind speed in km/h: 6 to 29
# 5. Rain: total day in mm: 0 to 16.8
# FWI Components
# 6. Fine Fuel Moisture Code (FFMC) index from the FWI system: 28.6 to 92.5
# 7. Duff Moisture Code (DMC) index from the FWI system: 1.1 to 65.9
# 8. Drought Code (DC) index from the FWI system: 7 to 220.4
# 9. Initial Spread Index (ISI) index from the FWI system: 0 to 18.5
# 10. Buildup Index (BUI) index from the FWI system: 1.1 to 68
# 11. Fire Weather Index (FWI) Index: 0 to 31.1
# 12. Classes: two classes, namely Fire and not Fire

# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# TO REMOVE FIRST LINE OF A DATASET AND WANTS TO MAKE SECOND LINE AS HEADER, WE CAN DO IT LIKE THIS header = 1 inside read_csv(......., header=1)like this

dataset=pd.read_csv("Algerian_forest_fires_dataset.csv")

# %%
dataset.head()
# Out:
#   day month  year Temperature  RH  Ws Rain   FFMC  DMC    DC  ISI  BUI  FWI  \
# 0   1     6  2012          29  57  18     0  65.7  3.4   7.6  1.3  3.4  0.5
# 1   2     6  2012          29  61  13   1.3  64.4  4.1   7.6    1  3.9  0.4
# 2   3     6  2012          26  82  22  13.1  47.1  2.5   7.1  0.3  2.7  0.1
# 3   4     6  2012          25  89  13   2.5  28.6  1.3   6.9    0  1.7    0
# 4   5     6  2012          27  77  16     0  64.8    3  14.2  1.2  3.9  0.5
#
#      Classes
# 0  not fire
# 1  not fire
# 2  not fire
# 3  not fire
# 4  not fire

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 247 entries, 0 to 246
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          246 non-null    object
#  1   month        245 non-null    object
#  2   year         245 non-null    object
#  3   Temperature  245 non-null    object
#  4    RH          245 non-null    object
#  5    Ws          245 non-null    object
#  6   Rain         245 non-null    object
#  7   FFMC         245 non-null    object
#  8   DMC          245 non-null    object
#  9   DC           245 non-null    object
#  10  ISI          245 non-null    object
#  11  BUI          245 non-null    object
#  12  FWI          245 non-null    object
#  13  Classes      244 non-null    object
# dtypes: object(14)
# memory usage: 27.1+ KB

# %% [markdown]
# ## Data cleaning

# %%
## missing value 

dataset.isnull().sum()
# Out:
# day            1
# month          2
# year           2
# Temperature    2
#  RH            2
#  Ws            2
# Rain           2
# FFMC           2
# DMC            2
# DC             2
# ISI            2
# BUI            2
# FWI            2
# Classes        3
# dtype: int64

# %%
## checking any missing value in any columns 

dataset[dataset.isnull().any(axis=1)]
# Out:
#                                day month  year Temperature   RH   Ws Rain   \
# 122                            NaN   NaN   NaN         NaN  NaN  NaN   NaN
# 123  Sidi-Bel Abbes Region Dataset   NaN   NaN         NaN  NaN  NaN   NaN
# 168                             14     7  2012          37   37   18   0.2
#
#      FFMC   DMC      DC   ISI   BUI      FWI Classes
# 122   NaN   NaN     NaN   NaN   NaN      NaN       NaN
# 123   NaN   NaN     NaN   NaN   NaN      NaN       NaN
# 168  88.9  12.9  14.6 9  12.5  10.4  fire          NaN

# %%
dataset.loc[:122,"Region"]=0
dataset.loc[122:,"Region"]=1
df=dataset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 247 entries, 0 to 246
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          246 non-null    object
#  1   month        245 non-null    object
#  2   year         245 non-null    object
#  3   Temperature  245 non-null    object
#  4    RH          245 non-null    object
#  5    Ws          245 non-null    object
#  6   Rain         245 non-null    object
#  7   FFMC         245 non-null    object
#  8   DMC          245 non-null    object
#  9   DC           245 non-null    object
#  10  ISI          245 non-null    object
#  11  BUI          245 non-null    object
#  12  FWI          245 non-null    object
#  13  Classes      244 non-null    object
#  14  Region       247 non-null    float64
# dtypes: float64(1), object(14)
# memory usage: 29.1+ KB

# %%
df[['Region']]=df[['Region']].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 247 entries, 0 to 246
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          246 non-null    object
#  1   month        245 non-null    object
#  2   year         245 non-null    object
#  3   Temperature  245 non-null    object
#  4    RH          245 non-null    object
#  5    Ws          245 non-null    object
#  6   Rain         245 non-null    object
#  7   FFMC         245 non-null    object
#  8   DMC          245 non-null    object
#  9   DC           245 non-null    object
#  10  ISI          245 non-null    object
#  11  BUI          245 non-null    object
#  12  FWI          245 non-null    object
#  13  Classes      244 non-null    object
#  14  Region       247 non-null    int64
# dtypes: int64(1), object(14)
# memory usage: 29.1+ KB

# %%
df.head()
# Out:
#   day month  year Temperature  RH  Ws Rain   FFMC  DMC    DC  ISI  BUI  FWI  \
# 0   1     6  2012          29  57  18     0  65.7  3.4   7.6  1.3  3.4  0.5
# 1   2     6  2012          29  61  13   1.3  64.4  4.1   7.6    1  3.9  0.4
# 2   3     6  2012          26  82  22  13.1  47.1  2.5   7.1  0.3  2.7  0.1
# 3   4     6  2012          25  89  13   2.5  28.6  1.3   6.9    0  1.7    0
# 4   5     6  2012          27  77  16     0  64.8    3  14.2  1.2  3.9  0.5
#
#      Classes    Region
# 0  not fire          0
# 1  not fire          0
# 2  not fire          0
# 3  not fire          0
# 4  not fire          0

# %%
df.isnull().sum()
# Out:
# day            1
# month          2
# year           2
# Temperature    2
#  RH            2
#  Ws            2
# Rain           2
# FFMC           2
# DMC            2
# DC             2
# ISI            2
# BUI            2
# FWI            2
# Classes        3
# Region         0
# dtype: int64

# %%
df.dropna()
# Out:
#     day month  year Temperature  RH  Ws Rain   FFMC  DMC    DC  ISI   BUI  \
# 0     1     6  2012          29  57  18     0  65.7  3.4   7.6  1.3   3.4
# 1     2     6  2012          29  61  13   1.3  64.4  4.1   7.6    1   3.9
# 2     3     6  2012          26  82  22  13.1  47.1  2.5   7.1  0.3   2.7
# 3     4     6  2012          25  89  13   2.5  28.6  1.3   6.9    0   1.7
# 4     5     6  2012          27  77  16     0  64.8    3  14.2  1.2   3.9
# ..   ..   ...   ...         ...  ..  ..   ...   ...  ...   ...  ...   ...
# 242  26     9  2012          30  65  14     0  85.4   16  44.5  4.5  16.9
# 243  27     9  2012          28  87  15   4.4  41.1  6.5     8  0.1   6.2
# 244  28     9  2012          27  87  29   0.5  45.9  3.5   7.9  0.4   3.4
# 245  29     9  2012          24  54  18   0.1  79.7  4.3  15.2  1.7   5.1
# 246  30     9  2012          24  64  15   0.2  67.3  3.8  16.5  1.2   4.8
#
#      FWI     Classes    Region
# 0    0.5   not fire          0
# ...

# %%
df.isnull().sum()
# Out:
# day            1
# month          2
# year           2
# Temperature    2
#  RH            2
#  Ws            2
# Rain           2
# FFMC           2
# DMC            2
# DC             2
# ISI            2
# BUI            2
# FWI            2
# Classes        3
# Region         0
# dtype: int64

# %%
df[df.isnull().any(axis=1)]
# Out:
#                                day month  year Temperature   RH   Ws Rain   \
# 122                            NaN   NaN   NaN         NaN  NaN  NaN   NaN
# 123  Sidi-Bel Abbes Region Dataset   NaN   NaN         NaN  NaN  NaN   NaN
# 168                             14     7  2012          37   37   18   0.2
#
#      FFMC   DMC      DC   ISI   BUI      FWI Classes    Region
# 122   NaN   NaN     NaN   NaN   NaN      NaN       NaN       1
# 123   NaN   NaN     NaN   NaN   NaN      NaN       NaN       1
# 168  88.9  12.9  14.6 9  12.5  10.4  fire          NaN       1

# %%
df.drop(index=[122, 123],inplace=True)

# %%
df[df.isnull().any(axis=1)]
# Out:
#     day month  year Temperature  RH  Ws Rain   FFMC   DMC      DC   ISI   BUI  \
# 168  14     7  2012          37  37  18   0.2  88.9  12.9  14.6 9  12.5  10.4
#
#          FWI Classes    Region
# 168  fire          NaN       1

# %%
df.columns = df.columns.str.strip()  # Remove leading/trailing spaces from column names
df['Classes'].fillna(df['Classes'].mode()[0], inplace=True)
# Out:
# C:\Users\AYAN SONI\AppData\Local\Temp\ipykernel_21284\604365893.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Classes'].fillna(df['Classes'].mode()[0], inplace=True)

# %%
df[df.isnull().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [day, month, year, Temperature, RH, Ws, Rain, FFMC, DMC, DC, ISI, BUI, FWI, Classes, Region]
# Index: []

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 245 entries, 0 to 246
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          245 non-null    object
#  1   month        245 non-null    object
#  2   year         245 non-null    object
#  3   Temperature  245 non-null    object
#  4   RH           245 non-null    object
#  5   Ws           245 non-null    object
#  6   Rain         245 non-null    object
#  7   FFMC         245 non-null    object
#  8   DMC          245 non-null    object
#  9   DC           245 non-null    object
#  10  ISI          245 non-null    object
#  11  BUI          245 non-null    object
#  12  FWI          245 non-null    object
#  13  Classes      245 non-null    object
#  14  Region       245 non-null    int64
# dtypes: int64(1), object(14)
# memory usage: 30.6+ KB

# %%
df=df.reset_index(drop=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 245 entries, 0 to 244
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          245 non-null    object
#  1   month        245 non-null    object
#  2   year         245 non-null    object
#  3   Temperature  245 non-null    object
#  4   RH           245 non-null    object
#  5   Ws           245 non-null    object
#  6   Rain         245 non-null    object
#  7   FFMC         245 non-null    object
#  8   DMC          245 non-null    object
#  9   DC           245 non-null    object
#  10  ISI          245 non-null    object
#  11  BUI          245 non-null    object
#  12  FWI          245 non-null    object
#  13  Classes      245 non-null    object
#  14  Region       245 non-null    int64
# dtypes: int64(1), object(14)
# memory usage: 28.8+ KB

# %%
df.head()
# Out:
#   day month  year Temperature  RH  Ws  Rain  FFMC  DMC    DC  ISI  BUI  FWI  \
# 0   1     6  2012          29  57  18     0  65.7  3.4   7.6  1.3  3.4  0.5
# 1   2     6  2012          29  61  13   1.3  64.4  4.1   7.6    1  3.9  0.4
# 2   3     6  2012          26  82  22  13.1  47.1  2.5   7.1  0.3  2.7  0.1
# 3   4     6  2012          25  89  13   2.5  28.6  1.3   6.9    0  1.7    0
# 4   5     6  2012          27  77  16     0  64.8    3  14.2  1.2  3.9  0.5
#
#        Classes  Region
# 0  not fire          0
# 1  not fire          0
# 2  not fire          0
# 3  not fire          0
# 4  not fire          0

# %%
df.tail()

lst_col = ['Rain','FFMC', 'DMC', 'DC', 'ISI', 'BUI', 'FWI']

# %%
df.iloc[[122]]
# Out:
#      day  month  year  Temperature   RH   Ws   Rain  FFMC  DMC  DC  ISI  BUI  \
# 122  day  month  year  Temperature   RH   Ws  Rain   FFMC  DMC  DC  ISI  BUI
#
#      FWI    Classes  Region
# 122  FWI  Classes         1

# %%
df=df.drop(122).reset_index(drop=True)

# %%
df.iloc[[122]]
# Out:
#     day month  year Temperature  RH  Ws Rain  FFMC  DMC   DC  ISI  BUI  FWI  \
# 122   1     6  2012          32  71  12  0.7  57.1  2.5  8.2  0.6  2.8  0.2
#
#          Classes  Region
# 122  not fire          1

# %%
df.iloc[[122]]
# Out:
#     day month  year Temperature  RH  Ws Rain  FFMC  DMC   DC  ISI  BUI  FWI  \
# 122   1     6  2012          32  71  12  0.7  57.1  2.5  8.2  0.6  2.8  0.2
#
#          Classes  Region
# 122  not fire          1

# %%
df.columns
# Out:
# Index(['day', 'month', 'year', 'Temperature', 'RH', 'Ws', 'Rain', 'FFMC',
#        'DMC', 'DC', 'ISI', 'BUI', 'FWI', 'Classes', 'Region'],
#       dtype='object')

# %% [markdown]
# #### Changes the required columns as integer data type

# %%
## Changing datatype

df[['month','day','year','Temperature','RH','Ws']]=df[['month','day','year','Temperature','RH','Ws']].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          244 non-null    int64
#  1   month        244 non-null    int64
#  2   year         244 non-null    int64
#  3   Temperature  244 non-null    int64
#  4   RH           244 non-null    int64
#  5   Ws           244 non-null    int64
#  6   Rain         244 non-null    object
#  7   FFMC         244 non-null    object
#  8   DMC          244 non-null    object
#  9   DC           244 non-null    object
#  10  ISI          244 non-null    object
#  11  BUI          244 non-null    object
#  12  FWI          244 non-null    object
#  13  Classes      244 non-null    object
#  14  Region       244 non-null    int64
# dtypes: int64(7), object(8)
# memory usage: 28.7+ KB

# %% [markdown]
# #### Changing the other columns to float data datatype

# %%
objects=[features for features in df.columns if df[features].dtype=='O']

# %%
for i in objects:
    if i!='Classes':
        df[i]=df[i].astype(float)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[33], line 3
#       1 for i in objects:
#       2     if i!='Classes':
# ----> 3         df[i]=df[i].astype(float)
#
# File c:\Users\AYAN SONI\Desktop\ML_code\venv2\Lib\site-packages\pandas\core\generic.py:6643, in NDFrame.astype(self, dtype, copy, errors)
#    6637     results = [
#    6638         ser.astype(dtype, copy=copy, errors=errors) for _, ser in self.items()
#    6639     ]
#    6641 else:
#    6642     # else, only a single dtype is given
# -> 6643     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6644     res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6645     return res.__finalize__(self, method="astype")
#
# ...

# %%
df.iloc[[133]]
# Out:
#      day  month  year  Temperature  RH  Ws  Rain  FFMC   DMC    DC  ISI   BUI  \
# 133   12      6  2012           27  58  17   0.0  88.9  21.3  37.8  8.7  21.2
#
#       FWI  Classes  Region
# 133  12.9  fire          1

# %%
error_row=[]
for idx,row in df.iterrows():
    try:
        pass
    except ValueError:
        error_row.append(idx)

print(error_row)
# Out:
# []

# %%
## Finding the row which is causing a problem during conversion

mask = df[lst_col].apply(pd.to_numeric, errors='coerce').isna() & df[lst_col].notna()
invalid_rows = df[mask.any(axis=1)]
invalid_rows
# Out:
#      day  month  year  Temperature  RH  Ws  Rain  FFMC   DMC      DC   ISI  \
# 165   14      7  2012           37  37  18   0.2  88.9  12.9  14.6 9  12.5
#
#       BUI      FWI  Classes  Region
# 165  10.4  fire     fire          1

# %%
df.tail()
# Out:
#      day  month  year  Temperature  RH  Ws  Rain  FFMC   DMC    DC  ISI   BUI  \
# 239   26      9  2012           30  65  14   0.0  85.4  16.0  44.5  4.5  16.9
# 240   27      9  2012           28  87  15   4.4  41.1   6.5     8  0.1   6.2
# 241   28      9  2012           27  87  29   0.5  45.9   3.5   7.9  0.4   3.4
# 242   29      9  2012           24  54  18   0.1  79.7   4.3  15.2  1.7   5.1
# 243   30      9  2012           24  64  15   0.2  67.3   3.8  16.5  1.2   4.8
#
#      FWI       Classes  Region
# 239  6.5       fire          1
# 240    0   not fire          1
# 241  0.2   not fire          1
# 242  0.7   not fire          1
# 243  0.5  not fire           1

# %%
df[165, 'DC']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\AYAN SONI\Desktop\ML_code\venv2\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: (165, 'DC')
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 df[165, 'DC']
#
# ...

# %%
df.iloc[[164]]
# Out:
#      day  month  year  Temperature  RH  Ws  Rain  FFMC   DMC    DC  ISI   BUI  \
# 164   13      7  2012           39  45  13   0.6  85.2  11.3  10.4  4.2  10.9
#
#      FWI  Classes  Region
# 164  4.7  fire          1

# %%
df.drop((165, 'DC'), axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[40], line 1
# ----> 1 df.drop((165, 'DC'), axis=1)
#
# File c:\Users\AYAN SONI\Desktop\ML_code\venv2\Lib\site-packages\pandas\core\frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)   5442     errors: IgnoreRaise = "raise",
#    5443 ) -> DataFrame | None:
#    5444     """
#    5445     Drop specified labels from rows or columns.
#    5446
#    (...)   5579             weight  1.0     0.8
#    5580     """
# -> 5581     return super().drop(
#    5582         labels=labels,
#    5583         axis=axis,
#    5584         index=index,
#    5585         columns=columns,
#    5586         level=level,
#    5587         inplace=inplace,
#    5588         errors=errors,
#    5589     )
#
# ...

# %%
value = df.loc[165, 'DC']

# %%
value = 14.6

# %%
df.iloc[[165]]
# Out:
#      day  month  year  Temperature  RH  Ws  Rain  FFMC   DMC      DC   ISI  \
# 165   14      7  2012           37  37  18   0.2  88.9  12.9  14.6 9  12.5
#
#       BUI      FWI  Classes  Region
# 165  10.4  fire     fire          1

# %%
df.drop((165,'DC'), axis = 1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[44], line 1
# ----> 1 df.drop((165,'DC'), axis = 1)
#
# File c:\Users\AYAN SONI\Desktop\ML_code\venv2\Lib\site-packages\pandas\core\frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)   5442     errors: IgnoreRaise = "raise",
#    5443 ) -> DataFrame | None:
#    5444     """
#    5445     Drop specified labels from rows or columns.
#    5446
#    (...)   5579             weight  1.0     0.8
#    5580     """
# -> 5581     return super().drop(
#    5582         labels=labels,
#    5583         axis=axis,
#    5584         index=index,
#    5585         columns=columns,
#    5586         level=level,
#    5587         inplace=inplace,
#    5588         errors=errors,
#    5589     )
#
# ...

# %%
df.loc[165, 'DC'] = float(14.6)

# %%
df.head()
# Out:
#    day  month  year  Temperature  RH  Ws  Rain  FFMC  DMC    DC  ISI  BUI  \
# 0    1      6  2012           29  57  18   0.0  65.7  3.4   7.6  1.3  3.4
# 1    2      6  2012           29  61  13   1.3  64.4  4.1   7.6    1  3.9
# 2    3      6  2012           26  82  22  13.1  47.1  2.5   7.1  0.3  2.7
# 3    4      6  2012           25  89  13   2.5  28.6  1.3   6.9    0  1.7
# 4    5      6  2012           27  77  16   0.0  64.8  3.0  14.2  1.2  3.9
#
#    FWI      Classes  Region
# 0  0.5  not fire          0
# 1  0.4  not fire          0
# 2  0.1  not fire          0
# 3    0  not fire          0
# 4  0.5  not fire          0

# %%
df.drop((165,'DC'), axis = 1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[47], line 1
# ----> 1 df.drop((165,'DC'), axis = 1)
#
# File c:\Users\AYAN SONI\Desktop\ML_code\venv2\Lib\site-packages\pandas\core\frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)   5442     errors: IgnoreRaise = "raise",
#    5443 ) -> DataFrame | None:
#    5444     """
#    5445     Drop specified labels from rows or columns.
#    5446
#    (...)   5579             weight  1.0     0.8
#    5580     """
# -> 5581     return super().drop(
#    5582         labels=labels,
#    5583         axis=axis,
#    5584         index=index,
#    5585         columns=columns,
#    5586         level=level,
#    5587         inplace=inplace,
#    5588         errors=errors,
#    5589     )
#
# ...

# %%
df.loc[[165]]
# Out:
#      day  month  year  Temperature  RH  Ws  Rain  FFMC   DMC    DC   ISI  \
# 165   14      7  2012           37  37  18   0.2  88.9  12.9  14.6  12.5
#
#       BUI      FWI  Classes  Region
# 165  10.4  fire     fire          1

# %%
df.drop((165, "DC"), axis =1,inplace = True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[49], line 1
# ----> 1 df.drop((165, "DC"), axis =1,inplace = True)
#
# File c:\Users\AYAN SONI\Desktop\ML_code\venv2\Lib\site-packages\pandas\core\frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)   5442     errors: IgnoreRaise = "raise",
#    5443 ) -> DataFrame | None:
#    5444     """
#    5445     Drop specified labels from rows or columns.
#    5446
#    (...)   5579             weight  1.0     0.8
#    5580     """
# -> 5581     return super().drop(
#    5582         labels=labels,
#    5583         axis=axis,
#    5584         index=index,
#    5585         columns=columns,
#    5586         level=level,
#    5587         inplace=inplace,
#    5588         errors=errors,
# ...

# %%
df.head()
# Out:
#    day  month  year  Temperature  RH  Ws  Rain  FFMC  DMC    DC  ISI  BUI  \
# 0    1      6  2012           29  57  18   0.0  65.7  3.4   7.6  1.3  3.4
# 1    2      6  2012           29  61  13   1.3  64.4  4.1   7.6    1  3.9
# 2    3      6  2012           26  82  22  13.1  47.1  2.5   7.1  0.3  2.7
# 3    4      6  2012           25  89  13   2.5  28.6  1.3   6.9    0  1.7
# 4    5      6  2012           27  77  16   0.0  64.8  3.0  14.2  1.2  3.9
#
#    FWI      Classes  Region
# 0  0.5  not fire          0
# 1  0.4  not fire          0
# 2  0.1  not fire          0
# 3    0  not fire          0
# 4  0.5  not fire          0

# %%
df.loc[[165]]
# Out:
#      day  month  year  Temperature  RH  Ws  Rain  FFMC   DMC    DC   ISI  \
# 165   14      7  2012           37  37  18   0.2  88.9  12.9  14.6  12.5
#
#       BUI      FWI  Classes  Region
# 165  10.4  fire     fire          1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          244 non-null    int64
#  1   month        244 non-null    int64
#  2   year         244 non-null    int64
#  3   Temperature  244 non-null    int64
#  4   RH           244 non-null    int64
#  5   Ws           244 non-null    int64
#  6   Rain         244 non-null    float64
#  7   FFMC         244 non-null    float64
#  8   DMC          244 non-null    float64
#  9   DC           244 non-null    object
#  10  ISI          244 non-null    object
#  11  BUI          244 non-null    object
#  12  FWI          244 non-null    object
#  13  Classes      244 non-null    object
#  14  Region       244 non-null    int64
# dtypes: float64(3), int64(7), object(5)
# memory usage: 28.7+ KB

# %%
df.head()
# Out:
#    day  month  year  Temperature  RH  Ws  Rain  FFMC  DMC    DC  ISI  BUI  \
# 0    1      6  2012           29  57  18   0.0  65.7  3.4   7.6  1.3  3.4
# 1    2      6  2012           29  61  13   1.3  64.4  4.1   7.6    1  3.9
# 2    3      6  2012           26  82  22  13.1  47.1  2.5   7.1  0.3  2.7
# 3    4      6  2012           25  89  13   2.5  28.6  1.3   6.9    0  1.7
# 4    5      6  2012           27  77  16   0.0  64.8  3.0  14.2  1.2  3.9
#
#    FWI      Classes  Region
# 0  0.5  not fire          0
# 1  0.4  not fire          0
# 2  0.1  not fire          0
# 3    0  not fire          0
# 4  0.5  not fire          0

# %%
for i in objects:
    if i!='Classes':
        df[i]=df[i].astype(float)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[54], line 3
#       1 for i in objects:
#       2     if i!='Classes':
# ----> 3         df[i]=df[i].astype(float)
#
# File c:\Users\AYAN SONI\Desktop\ML_code\venv2\Lib\site-packages\pandas\core\generic.py:6643, in NDFrame.astype(self, dtype, copy, errors)
#    6637     results = [
#    6638         ser.astype(dtype, copy=copy, errors=errors) for _, ser in self.items()
#    6639     ]
#    6641 else:
#    6642     # else, only a single dtype is given
# -> 6643     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6644     res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6645     return res.__finalize__(self, method="astype")
#
# ...

# %%
mask = df[lst_col].apply(pd.to_numeric, errors='coerce').isna() & df[lst_col].notna()
invalid_rows = df[mask.any(axis=1)]
invalid_rows
# Out:
#      day  month  year  Temperature  RH  Ws  Rain  FFMC   DMC    DC   ISI  \
# 165   14      7  2012           37  37  18   0.2  88.9  12.9  14.6  12.5
#
#       BUI      FWI  Classes  Region
# 165  10.4  fire     fire          1

# %%
# Convert 'FWI' column to numeric, coercing errors to NaN
# df['FWI'] = pd.to_numeric(df['FWI'], errors='coerce')
# Replace the problematic value at row 165 with the median of valid FWI values
# Only replace the problematic 'fire   ' value at row 165 in 'FWI' with the median, keep all other values unchanged
df.loc[165, 'FWI'] = df[df['FWI'] != '4.2']['FWI'].astype(float).median()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[56], line 5
#       1 # Convert 'FWI' column to numeric, coercing errors to NaN
#       2 # df['FWI'] = pd.to_numeric(df['FWI'], errors='coerce')
#       3 # Replace the problematic value at row 165 with the median of valid FWI values
#       4 # Only replace the problematic 'fire   ' value at row 165 in 'FWI' with the median, keep all other values unchanged
# ----> 5 df.loc[165, 'FWI'] = df[df['FWI'] != '4.2']['FWI'].astype(float).median()
#
# File c:\Users\AYAN SONI\Desktop\ML_code\venv2\Lib\site-packages\pandas\core\generic.py:6643, in NDFrame.astype(self, dtype, copy, errors)
#    6637     results = [
#    6638         ser.astype(dtype, copy=copy, errors=errors) for _, ser in self.items()
#    6639     ]
#    6641 else:
#    6642     # else, only a single dtype is given
# ...

# %%
df.head()
# Out:
#    day  month  year  Temperature  RH  Ws  Rain  FFMC  DMC    DC  ISI  BUI  \
# 0    1      6  2012           29  57  18   0.0  65.7  3.4   7.6  1.3  3.4
# 1    2      6  2012           29  61  13   1.3  64.4  4.1   7.6  1.0  3.9
# 2    3      6  2012           26  82  22  13.1  47.1  2.5   7.1  0.3  2.7
# 3    4      6  2012           25  89  13   2.5  28.6  1.3   6.9  0.0  1.7
# 4    5      6  2012           27  77  16   0.0  64.8  3.0  14.2  1.2  3.9
#
#    FWI      Classes  Region
# 0  0.5  not fire          0
# 1  0.4  not fire          0
# 2  0.1  not fire          0
# 3    0  not fire          0
# 4  0.5  not fire          0

# %%
df.iloc[[165]]
# Out:
#      day  month  year  Temperature  RH  Ws  Rain  FFMC   DMC    DC   ISI  \
# 165   14      7  2012           37  37  18   0.2  88.9  12.9  14.6  12.5
#
#       BUI      FWI  Classes  Region
# 165  10.4  fire     fire          1

# %%
df['FWI'].mode()
# Out:
# 0    0.4
# Name: FWI, dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          244 non-null    int64
#  1   month        244 non-null    int64
#  2   year         244 non-null    int64
#  3   Temperature  244 non-null    int64
#  4   RH           244 non-null    int64
#  5   Ws           244 non-null    int64
#  6   Rain         244 non-null    float64
#  7   FFMC         244 non-null    float64
#  8   DMC          244 non-null    float64
#  9   DC           244 non-null    float64
#  10  ISI          244 non-null    float64
#  11  BUI          244 non-null    float64
#  12  FWI          244 non-null    object
#  13  Classes      244 non-null    object
#  14  Region       244 non-null    int64
# dtypes: float64(6), int64(7), object(2)
# memory usage: 28.7+ KB

# %%
## Let's save the cleaned dataset 
df.to_csv('Algerian_forest_fires_cleaned_dataset.csv',index=False)

# %% [markdown]
# ### Exploratory Data Analysis

# %%
## Drop day, month, year
df_copy=df.drop(['day','month','year'], axis=1)

# %%
## Categories in classes 
df_copy['Classes'].value_counts()
# Out:
# Classes
# fire             132
# not fire         101
# fire               4
# fire               2
# not fire           2
# not fire           1
# not fire           1
# not fire           1
# Name: count, dtype: int64

# %%
df_copy.head()
# Out:
#    Temperature  RH  Ws  Rain  FFMC  DMC    DC  ISI  BUI  FWI      Classes  \
# 0           29  57  18   0.0  65.7  3.4   7.6  1.3  3.4  0.5  not fire
# 1           29  61  13   1.3  64.4  4.1   7.6  1.0  3.9  0.4  not fire
# 2           26  82  22  13.1  47.1  2.5   7.1  0.3  2.7  0.1  not fire
# 3           25  89  13   2.5  28.6  1.3   6.9  0.0  1.7    0  not fire
# 4           27  77  16   0.0  64.8  3.0  14.2  1.2  3.9  0.5  not fire
#
#    Region
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0

# %%
## Encoding of the categories in classes
df_copy['Classes']=np.where(df_copy['Classes'].str.contains('not fire'),0,1)

# %%
df_copy.head()
# Out:
#    Temperature  RH  Ws  Rain  FFMC  DMC    DC  ISI  BUI  FWI  Classes  Region
# 0           29  57  18   0.0  65.7  3.4   7.6  1.3  3.4  0.5        0       0
# 1           29  61  13   1.3  64.4  4.1   7.6  1.0  3.9  0.4        0       0
# 2           26  82  22  13.1  47.1  2.5   7.1  0.3  2.7  0.1        0       0
# 3           25  89  13   2.5  28.6  1.3   6.9  0.0  1.7    0        0       0
# 4           27  77  16   0.0  64.8  3.0  14.2  1.2  3.9  0.5        0       0

# %%
df_copy.tail()
# Out:
#      Temperature  RH  Ws  Rain  FFMC   DMC    DC  ISI   BUI  FWI  Classes  \
# 239           30  65  14   0.0  85.4  16.0  44.5  4.5  16.9  6.5        1
# 240           28  87  15   4.4  41.1   6.5   8.0  0.1   6.2    0        0
# 241           27  87  29   0.5  45.9   3.5   7.9  0.4   3.4  0.2        0
# 242           24  54  18   0.1  79.7   4.3  15.2  1.7   5.1  0.7        0
# 243           24  64  15   0.2  67.3   3.8  16.5  1.2   4.8  0.5        0
#
#      Region
# 239       1
# 240       1
# 241       1
# 242       1
# 243       1

# %%
df_copy['Classes'].value_counts()
# Out:
# Classes
# 1    138
# 0    106
# Name: count, dtype: int64

# %%
df_copy['Classes'].value_counts()
# Out:
# Classes
# 1    138
# 0    106
# Name: count, dtype: int64

# %%
## Plot density plot for all features 

plt.style.use('seaborn-v0_8')  ## updated version of matplotlib uses 'seaborn-v0_8'
df_copy.hist(bins=50, figsize=(20, 15))
plt.show()

# %%
## Percentage for Pie Chart 
percentage=df_copy['Classes'].value_counts(normalize=True)*100

# %%
## Plotting pie chart 

classlabels=["Fire", "Not Fire"]
plt.figure(figsize=(12,7))
plt.pie(percentage,labels=classlabels,autopct='%1.1f%%')
plt.title("Pie Chart of Classes")
# Out:
# Text(0.5, 1.0, 'Pie Chart of Classes')

# %%
## Correlation

# Print indices where 'FWI' column has the value 'fire   '
# for idx, value in df_copy['FWI'].items():
#     if value == 'fire   ':
#         print(idx)
# Out:
# 165

# %%
df_copy['Classes'].value_counts()
# Out:
# Classes
# 1    138
# 0    106
# Name: count, dtype: int64

# %%
# df_copy.drop(index=165).reset_index(drop=True)
# Out:
#      Temperature  RH  Ws  Rain  FFMC   DMC    DC  ISI   BUI  FWI  Classes  \
# 0             29  57  18   0.0  65.7   3.4   7.6  1.3   3.4  0.5        0
# 1             29  61  13   1.3  64.4   4.1   7.6  1.0   3.9  0.4        0
# 2             26  82  22  13.1  47.1   2.5   7.1  0.3   2.7  0.1        0
# 3             25  89  13   2.5  28.6   1.3   6.9  0.0   1.7    0        0
# 4             27  77  16   0.0  64.8   3.0  14.2  1.2   3.9  0.5        0
# ..           ...  ..  ..   ...   ...   ...   ...  ...   ...  ...      ...
# 238           30  65  14   0.0  85.4  16.0  44.5  4.5  16.9  6.5        1
# 239           28  87  15   4.4  41.1   6.5   8.0  0.1   6.2    0        0
# 240           27  87  29   0.5  45.9   3.5   7.9  0.4   3.4  0.2        0
# 241           24  54  18   0.1  79.7   4.3  15.2  1.7   5.1  0.7        0
# 242           24  64  15   0.2  67.3   3.8  16.5  1.2   4.8  0.5        0
#
#      Region
# 0         0
# 1         0
# 2         0
# 3         0
# ...

# %%
df_copy.iloc[[165]]
# Out:
#      Temperature  RH  Ws  Rain  FFMC   DMC    DC   ISI   BUI      FWI  \
# 165           37  37  18   0.2  88.9  12.9  14.6  12.5  10.4  fire
#
#      Classes  Region
# 165        1       1

# %%
df_copy.head()
# Out:
#    Temperature  RH  Ws  Rain  FFMC  DMC    DC  ISI  BUI  FWI  Classes  Region
# 0           29  57  18   0.0  65.7  3.4   7.6  1.3  3.4  0.5        0       0
# 1           29  61  13   1.3  64.4  4.1   7.6  1.0  3.9  0.4        0       0
# 2           26  82  22  13.1  47.1  2.5   7.1  0.3  2.7  0.1        0       0
# 3           25  89  13   2.5  28.6  1.3   6.9  0.0  1.7    0        0       0
# 4           27  77  16   0.0  64.8  3.0  14.2  1.2  3.9  0.5        0       0

# %%
## Replacing 'fire   ' in the column with the mode of the value of the column

FWI_mode = df_copy.loc[df_copy['FWI'] !='fire   ', 'FWI'].mode()[0]

## Here replacing 'fire   ' with the mode 

df_copy['FWI'] = df_copy['FWI'].replace('fire   ', FWI_mode)

# %%
df_copy['FWI'].values
# Out:
# array(['0.5', '0.4', '0.1', '0', '0.5', '2.5', '7.2', '7.1', '0.3', '0.9',
#        '5.6', '7.1', '0.2', '0.4', '0.1', '0', '0', '0.2', '1.4', '0.4',
#        '2.2', '2.3', '3.8', '7.5', '8.4', '10.6', '15', '13.9', '3.9',
#        '12.9', '0.4', '0.3', '0.5', '1.7', '4.9', '6.8', '3.2', '8',
#        '0.6', '0.5', '2.2', '0.9', '3.4', '0.8', '0.5', '0.4', '3.6', '6',
#        '10.9', '4', '8.8', '2.8', '2.1', '1.3', '7.3', '15.3', '15.3',
#        '11.3', '11.9', '10.7', '15.7', '0.9', '0.8', '0.8', '3.9', '6.1',
#        '6.8', '8', '2.6', '9.9', '11.6', '12.1', '4.2', '10.2', '10.6',
#        '6.3', '4.2', '14.6', '16.1', '17.2', '16.8', '18.4', '20.4',
#        '22.3', '20.9', '20.3', '13.7', '13.2', '19.9', '30.2', '4.2',
#        '0.3', '0.1', '0', '0', '0.5', '1.7', '0.9', '0.6', '0.4', '0.2',
#        '0.3', '0.3', '0.5', '0', '0.1', '0', '0.8', '5.9', '7.7', '9.7',
#        '6.3', '8.3', '2.8', '0.7', '0.7', '0.1', '1.7', '4.1', '0.9',
# ...

# %%
FWI_mode
# Out:
# '0.4'

# %%
df_copy.corr()
# Out:
#              Temperature        RH        Ws      Rain      FFMC       DMC  \
# Temperature     1.000000 -0.654443 -0.278132 -0.326786  0.677491  0.483105
# RH             -0.654443  1.000000  0.236084  0.222968 -0.645658 -0.405133
# Ws             -0.278132  0.236084  1.000000  0.170169 -0.163255 -0.001246
# Rain           -0.326786  0.222968  0.170169  1.000000 -0.544045 -0.288548
# FFMC            0.677491 -0.645658 -0.163255 -0.544045  1.000000  0.602391
# DMC             0.483105 -0.405133 -0.001246 -0.288548  0.602391  1.000000
# DC              0.370498 -0.220330  0.076245 -0.296804  0.503910  0.875358
# ISI             0.607551 -0.690637  0.015248 -0.347105  0.739730  0.674499
# BUI             0.455504 -0.348587  0.029756 -0.299171  0.589652  0.982073
# FWI             0.558800 -0.570483  0.029001 -0.322810  0.686342  0.874924
# Classes         0.518119 -0.435023 -0.066529 -0.379449  0.770114  0.584188
# ...

# %%
sns.heatmap(df_copy.corr())
# Out:
# <Axes: >

# %%
## Box Plot 
plt.figure(figsize=(10, 5))
sns.boxplot(x=pd.to_numeric(df_copy['FWI'], errors='coerce'),color='orange')
plt.xlabel('FWI')
plt.title('Box Plot of FWI')
plt.tight_layout()
plt.show()

# %%
df.head()
# Out:
#    day  month  year  Temperature  RH  Ws  Rain  FFMC  DMC    DC  ISI  BUI  \
# 0    1      6  2012           29  57  18   0.0  65.7  3.4   7.6  1.3  3.4
# 1    2      6  2012           29  61  13   1.3  64.4  4.1   7.6  1.0  3.9
# 2    3      6  2012           26  82  22  13.1  47.1  2.5   7.1  0.3  2.7
# 3    4      6  2012           25  89  13   2.5  28.6  1.3   6.9  0.0  1.7
# 4    5      6  2012           27  77  16   0.0  64.8  3.0  14.2  1.2  3.9
#
#    FWI      Classes  Region
# 0  0.5  not fire          0
# 1  0.4  not fire          0
# 2  0.1  not fire          0
# 3    0  not fire          0
# 4  0.5  not fire          0

# %%
df['Classes']=np.where(df['Classes'].str.contains('not fire'),'not fire','fire')

# %%
## Monthly analysis of the fire 

dftemp=df.loc[df['Region']==1]
plt.subplots(figsize=(13,6))
sns.set_style('whitegrid')
sns.countplot(x='month', hue='Classes', data=df)
plt.ylabel('Number of fires',weight='bold')
plt.xlabel('Months',weight='bold')
plt.title("Fire Anlysis of Sidi- Bel Region",weight='bold')
# Out:
# Text(0.5, 1.0, 'Fire Anlysis of Sidi- Bel Region')

# %%
dftemp=df.loc[df['Region']==0]
plt.subplots(figsize=(13,6))
sns.set_style('whitegrid')
sns.countplot(x='month', hue='Classes', data=df)
plt.ylabel('Number of fires',weight='bold')
plt.xlabel('Months',weight='bold')
plt.title("Fire Anlysis of Bejaia Region",weight='bold')
# Out:
# Text(0.5, 1.0, 'Fire Anlysis of Bejaia Region')

# %% [markdown]
# Its observed that August and September had most of the forest fires for both regions. And from the above plot of months, we can understand few things
#
# Most of the fires happend in August and very high Fires happend in only 3 months - June, July and August.
#
# Less Fires was on September
